# %% [markdown]
# ## Notas de aula: Teoria de Grupos, Autor: Jonas Maziero, Departamento de Física, UFSM

# %%
# %run /Users/jonasmaziero/Dropbox/GitHub/algebra_linear/init.ipynb

# %% [markdown]
# # O grupo de Lorentz
#
# ## Mecânica Newtoniana e transformações de Galilei
# ### Procedimentos gerais da mecânica:
# * A partir do movimento, de medidas de posição, podemos inferir as forças:
# \begin{equation}
# \vec{r}(t)\rightarrow\vec{v}(t)=\frac{d\vec{r}(t)}{dt}\rightarrow\vec{a}(t)=\frac{d\vec{v}(t)}{dt}\rightarrow\vec{F}(t)=m\vec{a}(t).
# \end{equation}
# * A partir das forças, e condições iniciais, podemos prever o movimento:
# \begin{equation}
# \vec{a}(t)=\frac{\vec{F}(t)}{m}\rightarrow \vec{v}(t)=\vec{v}(t_{0})+\int_{t_{0}}^{t}\vec{a}(t')dt'\rightarrow\vec{r}(t)=\vec{r}(t_{0})+\int_{t_{0}}^{t}\vec{v}(t')dt'.
# \end{equation}
#
# ### Descrição do movimento por observadores em movimento relativo
# Consideremos dois observadores $O$ e $O'$ em movimento relativo com velocidade constante $\vec{V}$, como ilustrado na figura abaixo.
#
# <img src="ref_frame.png" width="400">

# %% [markdown]
# __Postulado__: O tempo é absoluto, i.e., o tempo medido por todos os relógios é o mesmo, independente de sua velocidade. Aqui $t=t'$.
#
# Pela soma vetorial obteremos as chamadas _transformações de Galilei_ (TG), que relacionam as coordenadas espaço-temporais de uma partícula em diferentes referenciais inerciais (RIs):
# \begin{equation}
# \vec{r}=\vec{V}t+\vec{r}'\text{ }\therefore \text{ }\vec{r}'=\vec{r}-\vec{V}t.
# \end{equation}
#
# Não é difícil verificar que a 2ª lei de Newton é invariante por TG:
# \begin{align}
# \vec{F}' & = m\vec{a}' = m\frac{d^{2}\vec{r}'}{dt'^{2}} \\
# & = m\frac{d^{2}(\vec{r}-\vec{V}t)}{dt^{2}} = m\frac{d(\vec{v}-\vec{V})}{dt} = m(\vec{a}-\vec{0}) = \vec{F}.
# \end{align}

# %% [markdown]
# ## Mecânica Einsteiniana e transformações de Lorentz
#
# Existiam duas motivações fortes para o desenvolvimento de uma mecânica melhor que a Newtoniana. As eqs. de Maxwell não são invariantes por TG. Ademais o experimento de Michelson e Morley indicou que a velocidade da luz no vácuo é a mesma para todos os referenciais.
#
# Postulados da teoria da _relatividade restrita_:<br>
# __P1.__ RIs devem ser equivalemtes no que concerne as leis físicas.<br>
# __P2.__ A velocidade da luz no vácuo é a mesma, $c$, quando medida em todos os RIs.
#
# ### Tranformações de Lorentz
# Esses postulados nos fornecerão relações distintas das TG para as coordenadas de uma partícula em diferentes RIs. Aqui assumiremos movimento relativo entre os RIs em uma única direção, $x$. Nesse caso as TG ficam
# \begin{align}
# & x=x'+V_{x}t'=x'+Vt\text{ }\therefore \text{ }x'=x-Vt, \\
# & y=y'+V_{y}t'=y'+0t\text{, }\therefore \text{ }y'=y, \\
# & z=z'+V_{z}t'=z'+0t\text{, }\therefore \text{ }z'=z.
# \end{align}
#
# Uma possibilidade para obtermos as tranformações de Lorentz é usar uma correção relativística global $\gamma$ para as TG, i.e., teríamos $y=y'$, $z=z'$ e
# \begin{equation}
# x'=\gamma(x-Vt).
# \end{equation}
# Por P1 teremos
# \begin{equation}
# x=\gamma(x'+Vt').
# \end{equation}
# _OBS._ Aqui não assumimos que o tempo é absoluto, como era o caso na mecânica Newtoniana. <br>
# Manipulando essas equações,
# \begin{equation}
# x=\gamma(x'+Vt')=\gamma(\gamma(x-Vt)+Vt')=\gamma^{2}(x-Vt)+\gamma Vt'.
# \end{equation}
# Com isso obtemos a seguinte relação entre o tempo medido pelo observador $O'$ com aquele medido por $O$:
# \begin{equation}
# t'=\gamma\left(t+\frac{1-\gamma^{2}}{\gamma^{2}V}x\right).
# \end{equation}

# %% [markdown]
# __Exercício:__ Verifique que
# \begin{equation}
# t=\gamma\left(t'-\frac{1-\gamma^{2}}{\gamma^{2}V}x'\right),
# \end{equation}
# que é compatível com P1.
#
# O que ainda nos falta é obter a correção relativística $\gamma$. Pra isso podemos utilizar o seguinte experimento de pensamento. Quando $O$ e $O'$ estão na mesma posição, um pulso esférico de luz é emitido. Por P2 devemos ter
# \begin{align}
# & R^{2}=x^{2}+y^{2}+z^{2}=c^{2}t^{2}, \\
# & R'^{2}=x'^{2}+y'^{2}+z'^{2}=c^{2}t'^{2}.
# \end{align}
# Agora substituimos as coordenadas de um referencial em relação às do outro, manipulamos a eq. e exigimos que ela seja equivalente à outra. Para $R'^{2}$
# \begin{align}
# & (\gamma(x-Vt))^{2}+y^{2}+z^{2}=c^{2}((\gamma(t-(1-\gamma^{2})x/\gamma^{2}V))^{2}) \\
# & \therefore \gamma^{2}x^{2} +\gamma^{2}V^{2}t^{2}-\gamma^{2}2xVt+y^{2}+z^{2}=c^{2}\gamma^{2}t^{2}+c^{2}\gamma^{2}(1-\gamma^{2})^{2}x^{2}/\gamma^{4}V^{2}-c^{2}\gamma^{2}2t(1-\gamma^{2})x/\gamma^{2}V) \\
# & \therefore Ax^{2} + y^{2}+z^{2}=\gamma^{2}(1-V^{2}/c^{2})c^{2}t^{2} + Bxt.
# \end{align}
#
# __Exercício:__ Obtenha $A$ e $B$.
#
# Pela equivalência com a eq. para $R^{2}$ devemos ter $A=1$, $B=0$ e
# \begin{equation}
# \gamma^{2}(1-V^{2}/c^{2})=1\Rightarrow \gamma=\frac{1}{\sqrt{1-V^{2}/c^{2}}}=\gamma(V).
# \end{equation}
#
# __Exercício:__ Verifique que
# \begin{equation}
# \frac{1-\gamma^{2}}{\gamma^{2}} = -\frac{V^{2}}{c^{2}},
# \end{equation}
# e assim
# \begin{equation}
# t'=\gamma\left(t-\frac{V}{c^{2}}x\right)\text{ e } t=\gamma\left(t'+\frac{V}{c^{2}}x'\right).
# \end{equation}

# %% [markdown]
# ## Grupo de Lorentz
# Para obter os elementos do grupo de Lorentz, primeiramente representaremos as coordenadas espaço-temporais de uma partícula como vetores coluna (quadrivetores):
# \begin{equation}
# \rho=\begin{bmatrix} x \\ y \\ z \\ ct \end{bmatrix} \text{, } \rho'=\begin{bmatrix}x' \\ y' \\ z' \\ ct' \end{bmatrix}.
# \end{equation}
# Pode-se verificar que \begin{equation} \rho'=\Lambda(V)\rho \end{equation} com
# \begin{equation}
# \Lambda(V)=\begin{bmatrix} \gamma(V) & 0 & 0 & -\gamma(V)V/c \\ 0&1&0&0 \\ 0&0&1&0 \\ -\gamma(V)V/c&0&0&\gamma(V) \end{bmatrix},
# \end{equation}
# que serão os elementos do grupo de Lorentz, cuja operação de composição é o produto matricial.
#
# ### Verificação da estrutura de grupo
# Usando o código abaixo, podemos verificar que o elemento identidade é $\Lambda(0)=\mathbb{I}_{4}$ e que o elemento inverso de $\Lambda(V)$ é $\Lambda(-V)$, i.e., $\Lambda(V)\Lambda(-V)=\Lambda(0)$. Associatividade vem da associatividade do produto matricial. Quanto à composição, temos que
# \begin{equation}
# \Lambda(V)\Lambda(V')= \begin{bmatrix} \gamma(V)\gamma(V')(1+VV'/c^{2})&0&0&-\gamma(V)\gamma(V')(V+V')/c \\ 0&1&0&0 \\ 0&0&1&0 \\ -\gamma(V)\gamma(V')(V+V')/c&0&0&\gamma(V)\gamma(V')(1+VV'/c^{2}) \end{bmatrix}.
# \end{equation}

# %%
# usa V'=v
L, g, V, c, v = symbols("Lambda gamma V c v")
def g(V): # correção relativística
    return 1/sqrt(1-V**2/c**2)
def L(V): # elementos do grupo de Lorentz
    return Matrix([[g(V),0,0,-g(V)*V/c],[0,1,0,0],[0,0,1,0],[-g(V)*V/c,0,0,g(V)]])
#L(V)
#L(0) # identidade
#simplify(L(V)*L(-V)) # inverso
L(V)*L(v) # composição
# Out:
# ⎡                V⋅v                                  1
# ⎢ ────────────────────────────────── + ───────────────────────────────    0  0
# ⎢          ________       __________         ________       __________
# ⎢         ╱      2       ╱    2             ╱      2       ╱    2
# ⎢  2     ╱      v       ╱    V             ╱      v       ╱    V
# ⎢ c ⋅   ╱   1 - ── ⋅   ╱   - ── + 1       ╱   1 - ── ⋅   ╱   - ── + 1
# ⎢      ╱         2    ╱       2          ╱         2    ╱       2
# ⎢    ╲╱         c   ╲╱       c         ╲╱         c   ╲╱       c
# ⎢
# ⎢                                   0                                     1  0
# ⎢
# ⎢                                   0                                     0  1
# ⎢
# ⎢                  V                                   v
# ⎢- ───────────────────────────────── - ─────────────────────────────────  0  0
# ⎢          ________       __________           ________       __________
# ...

# %% [markdown]
# Aplicando a composição relativística de velocidades descrita abaixo para os três referenciais como movimentos relativos como na seguinte figura
#
# <img src="ref_frame_.png" width="500">,
#
# teremos que a velocidade de $O''$ (a partícula nesse caso) em relação a $O$ será ($u_{y}=u_{z}=0$ aqui e $V''=u$ e $V'=u'$) (__exercício__):
# \begin{equation}
# V''=\frac{V+V'}{1+VV'/c^{2}}.
# \end{equation}

# %%
# usa V''=U
def U(V,v):
    return (V+v)/(1+V*v/c**2)
#U(V,v)
#L(U(V,v))
simplify(L(U(V,v))-L(V)*L(v))
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                 V⋅v                                1
# ⎢- ────────────────────────────────── + ──────────────────────────── - ───────
# ⎢           ________       __________            ___________________         _
# ⎢          ╱      2       ╱    2                ╱               2           ╱
# ⎢   2     ╱      v       ╱    V                ╱         (V + v)           ╱
# ⎢  c ⋅   ╱   1 - ── ⋅   ╱   - ── + 1          ╱   1 - ─────────────       ╱
# ⎢       ╱         2    ╱       2             ╱                    2      ╱
# ⎢     ╲╱         c   ╲╱       c             ╱          2 ⎛V⋅v    ⎞     ╲╱
# ⎢                                          ╱          c ⋅⎜─── + 1⎟
# ⎢                                         ╱              ⎜  2    ⎟
# ⎢                                       ╲╱               ⎝ c     ⎠
# ⎢
# ⎢                                                  0
# ⎢
# ⎢                                                  0
# ⎢
# ...

# %% [markdown]
# Nesse caso o código não nos ajudou muito. Então verifiquemos na mão que $\Lambda(V'')=\Lambda(V)\Lambda(V')$. Para isso devemos ter que
# \begin{align}
# & \gamma(V'')=\gamma(V)\gamma(V')(1+VV'/c^{2}), \\
# & -\gamma(V'')V''/c = -\gamma(V)\gamma(V')(V+V')/c.
# \end{align}
#
# Começamos invertendo a primeira eq. e a elevando ao quadrado:
# \begin{align}
# & \frac{(1+VV'/c^{2})^{2}}{\gamma(V'')^{2}} = \frac{1}{\gamma(V)^{2}\gamma(V')^{2}} \\
# & \Rightarrow (1+VV'/c^{2})^{2}(1-V''^{2}/c^{2}) = (1-V^{2}/c^{2})(1-V'^{2}/c^{2}) \\
# & \Rightarrow 1+2VV'/c^{2}+V^{2}V'^{2}/c^{4}-(V''^{2}/c^{2})(1+VV'/c^{2})^{2} = 1-V'^{2}/c^{2}-V^{2}/c^{2}+V^{2}V'^{2}/c^{4} \\
# & \Rightarrow V'^{2}+V^{2}+2VV' = (V+V')^{2} = V''^{2}(1+VV'/c^{2})^{2} \\
# & \Rightarrow V''=(V+V')/(1+VV'/c^{2}),
# \end{align}
# que é a expressão correta.
#
# __Exercício:__ Verifique a segunda eq.
#
# Com isso mostramos fechamento para o grupo de Lorentz.

# %% [markdown]
# ### Composição relativística de velocidades
# Na mecânica Newtoniana, se uma partícula possui velocidade $\vec{u}$($\vec{u}'$) em relação a um referencial inercial $O$($O'$) e a velocidade relativa dos referenciais é $\vec{V}=(V,0,0)$, então
# \begin{equation}
# \vec{u}'=(u_{x}',u_{y}',u_{z}')=(u_{x}+V,u_{y},u_{z}).
# \end{equation}
# Vejamos como fica essa relação no caso relaivístico. Considere a figura acima com movimento relativo dos referenciais somente na direção $x$. A velocidade da partícula em relação a $O$ é:
# \begin{equation}
# \vec{u}(t)=\frac{d\vec{r}(t)}{dt}=\left(\frac{dx(t)}{dt},\frac{dy(t)}{dt},\frac{dz(t)}{dt}\right)=(u_{x}(t),u_{y}(t),u_{z}(t)).
# \end{equation}
# Em relação a $O'$
# \begin{equation}
# \vec{u}'(t')=\frac{d\vec{r}'(t')}{dt'}=\left(\frac{dx'(t')}{dt'},\frac{dy'(t')}{dt'},\frac{dz'(t')}{dt'}\right)=(u_{x}'(t'),u_{y}'(t'),u_{z}'(t')).
# \end{equation}
# Usando $dx'=\gamma(dx-Vdt)$, $dy'=dy$, $dz'=dz$ e $dt'=\gamma(dt-(V/c^{2})dx)$ obtemos
# \begin{align}
# & u_{x}'=\frac{dx'(t')}{dt'}=\frac{\gamma(dx-Vdt)}{\gamma(dt-(V/c^{2})dx)} = \frac{u_{x}-V}{1-u_{x}V/c^{2}}, \\
# & u_{y}'=\frac{dy'(t')}{dt'}=\frac{dy}{\gamma(dt-(V/c^{2})dx)} = \frac{u_{y}}{\gamma(1-u_{x}V/c^{2})}, \\
# & u_{z}'=\frac{dz'(t')}{dt'}=\frac{dz}{\gamma(dt-(V/c^{2})dx)} = \frac{u_{z}}{\gamma(1-u_{x}V/c^{2})}.
# \end{align}

# %% [markdown]
# # Grupo de Poincaré
